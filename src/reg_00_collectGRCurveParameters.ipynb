# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools as it
import functools as ft
from tools import helpers as h
from copy import copy

from umap import UMAP
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Read in Super/sub cluster

# %%
louv = pd.read_csv('../data/cluster/louvain_clusters.txt', index_col=0, sep='\t')
louv.columns = ['cluster_super']
louv = louv.merge(pd.read_csv('../data/cluster/louvain_small_clusters.txt', index_col=0, sep='\t'), left_index=True, right_index=True)
louv.columns = ['cluster_super', 'cluster_sub']
louv.head()
# Out:
#        cluster_super  cluster_sub
# names
# MST1R              3           11
# YES1               3           11
# TYRO3              3           11
# FGR                3           11
# SRC                3           11

# %%
hgnc_mapper = h.fetch_hgnc_mapper()

# %%
# !ls ../data/grmetrics/
# Out:
# broad_hms_lincs.tsv     genentech_cell_line.tsv lincs_mcf10a.tsv
# ctrp.tsv                hms_lincs_density.tsv   mep_lincs.tsv

# %%
# initial target list -- not for linear programming
klaeger = pd.read_excel('../data/ref/Klaeger_Science_2017 Supplementary Table 6 Selectivities.xlsx', sheet_name='CATDS target')

# a number of drugs have very similar targets listed in the same row
# we parse to separate these out 
double_drug_targets = klaeger[klaeger['Target'].apply(lambda x: ';' in x)]

# get the first and second gene
first_genes = double_drug_targets['Target'].apply(lambda x: x.split(';')[0])
second_genes = double_drug_targets['Target'].apply(lambda x: x.split(';')[1])

# fix the double targets
repaired_double_targets = double_drug_targets.drop('Target', axis=1).assign(**{'Target':first_genes})
repaired_double_targets = repaired_double_targets.append(double_drug_targets.drop('Target', axis=1).assign(**{'Target':second_genes})) 
klaeger = klaeger.drop(double_drug_targets.index).append(repaired_double_targets, sort=False)

# filter to only hgnc keys
klaeger = klaeger[klaeger.Target.isin(hgnc_mapper.keys())]

# convert to hgnc
klaeger.Target = klaeger.Target.apply(lambda x: hgnc_mapper[x])

# filter to our kinases
klaeger = klaeger[klaeger.Target.isin(set(louv.index))]

# save total drug list information
drug_list = list(sorted(set(klaeger.Drug)))
print(len(drug_list), ' drugs present for our analysis')

# sort columns
klaeger = klaeger[['Target', 'Drug', 'At', 'CATDS']]

klaeger['Drug'] = [x.lower().replace('-', '') for x in klaeger.Drug]
klaeger.head()
# Out:
# 217  drugs present for our analysis
#      Target        Drug        At     CATDS
# 0     AURKA      mk5108  0.120921  0.657165
# 1     CHEK1    pf477736  0.243725  0.733257
# 2      FLT3   dovitinib  0.265240  0.860803
# 4       MET  capmatinib  0.337514  1.000000
# 5  MAPKAPK2       vx702  0.342705  0.743594

# %%
klaeger_drugs = set(klaeger.Drug)
print(len(klaeger_drugs), 'drugs in the Klaeger 2017 Science Paper with known targets')
# Out:
# 217 drugs in the Klaeger 2017 Science Paper with known targets

# %% [markdown]
# ### Examine the various GRMetrics datasets available -- we also want to see how much of Klaeger is present

# %%
datasets = ['broad_hms_lincs.tsv', 'genentech_cell_line.tsv', 
            'lincs_mcf10a.tsv', 'ctrp.tsv',
            'hms_lincs_density.tsv', 'mep_lincs.tsv']

abbrevs = ['broad_hms', 'genentech', 'lincs_mcf', 'ctrp', 'hms_density', 'mep']

datadict = {a:pd.read_csv('../data/grmetrics/'+d, sep='\t') for a,d in list(zip(abbrevs, datasets))}

for name,data in datadict.items():
    print(name,':\tsize',data.shape)
    display(data.head())
# Out:
# broad_hms :	size (642, 12)
#   Cell_HMSLID Cell_Line Small_Mol_HMSLID Small_Molecule      GR50     GEC50  \
# 0     50105-3     BT-20      10001-101-1     Seliciclib  5.677700  14.42560
# 1     50105-3     BT-20      10045-101-1        A443654  0.053033   0.23019
# 2     50105-3     BT-20      10133-101-1       Afatinib       inf   0.00000
# 3     50105-3     BT-20      10004-101-1        AT-7519  0.204440   0.32038
# 4     50105-3     BT-20      10158-101-1       AZD 5438  0.245910   0.55040
#
#       GRmax    GRinf  GR_Hill_Coeff   GR_AOC         GR_r2          pval
# 0  0.194160 -1.00000        1.17820  0.17548  9.722700e-01  7.689100e-04
# 1 -0.492210 -0.63357        0.55758  1.00120  9.874300e-01  1.579200e-04
# 2  0.054486  0.68319        0.01000  0.25541 -1.060000e-12  1.290800e-01
# 3 -0.401780 -0.40563        1.32240  0.86351  9.993600e-01  4.140000e-07
# 4 -0.354640 -0.44610        0.79155  0.74810  9.909100e-01  8.250000e-05
# genentech :	size (6167, 18)
#   Cell_Line  DoublingTime Tissue  Perturbagen       GR50        GEC50  \
# 0    1321N1            23  Brain      bid1870  31.000000  1000.000000
# 1    1321N1            23  Brain   bortezomib   0.045432     0.063644
# 2    1321N1            23  Brain   crizotinib   1.344200     2.197400
# 3    1321N1            23  Brain    docetaxel   0.004362     0.004333
# 4    1321N1            23  Brain  doxorubicin   0.128300     0.203860
#
#      GRmax     GRinf  GR_Hill_Coeff    GR_AOC    GR_r2       IC50      Emax  \
# 0  0.81607  0.388820        0.24661  0.066971  0.68658  31.000000  0.739340
# 1 -0.63780 -0.640180        2.44540  0.509780  0.99919   0.039072  0.004753
# 2  0.70570 -0.999270        2.23430  0.056496  0.67633   1.194200  0.607570
# 3  0.00624  0.004647        1.39340  0.482830  0.99431   0.003182  0.116440
# 4 -0.56468 -0.537030        1.57540  0.799740  0.99292   0.098516  0.008452
#
#        AUC    IC_r2 CDC73_del BCL2_del PTEN_mut
# 0  0.90021  0.68569       NaN      NaN      NaN
# 1  0.63654  0.99806       NaN      NaN      NaN
# 2  0.91825  0.60390       NaN      NaN      NaN
# 3  0.52438  0.99766       NaN      NaN      NaN
# 4  0.40325  0.99912       NaN      NaN      NaN
# lincs_mcf :	size (152, 10)
#          Cell_Line Small_Molecule     GR50    GEC50    GRmax    GRinf  \
# 0  Isolate 1 - HMS      Alpelisib  14.6463  76.5784  0.57934 -1.00000
# 1  Isolate 1 - HMS      Alpelisib   4.9885  28.7866  0.31350 -1.00000
# 2  Isolate 1 - HMS      Alpelisib   9.4622  49.3942  0.46986 -0.99998
# 3  Isolate 2 - HMS      Alpelisib  19.9827  54.4563  0.72384 -0.97835
# 4  Isolate 2 - HMS      Alpelisib  61.2517  17.9647  0.78534  0.37406
#
#    GR_Hill_Coeff    GR_AOC    GR_r2 Replicate
# 0        0.66416  0.085282  0.99239    HMS R1
# 1        0.62678  0.166000  0.99188    HMS R2
# 2        0.66480  0.106260  0.99083    HMS R3
# 3        1.08130  0.033366  0.98580    HMS R1
# 4        1.12410  0.028478  0.97344    HMS R2
# ctrp :	size (65945, 9)
#   Cell_Line                Perturbagen      GR50        GEC50    GRmax  \
# 0      786O  16-beta-bromoandrosterone       inf          inf  0.93115
# 1      786O                1S,3R-RSL-3  0.038678     0.047649 -0.89921
# 2      786O                  3-Cl-AHPC  0.952640     1.225600 -0.35674
# 3      786O                   A-804598       inf  1000.000000  0.76195
# 4      786O                   AA-COCF3       inf          inf  0.95043
#
#      GRinf  GR_Hill_Coeff    GR_AOC    GR_r2
# 0  0.93115        0.00000  0.020524  0.18804
# 1 -0.91886        5.00000  1.181700  0.99115
# 2 -0.33655        2.04240  0.515340  0.99784
# 3  0.31483        0.39217  0.063627  0.43201
# 4  0.95043        0.00000  0.002046  0.24800
# hms_density :	size (1008, 22)
#   Cell_HMSLID Cell_Line Small_Mol_HMSLID Small_Molecule  Replicate  Density  \
# 0     50029-3      MCF7      10024-101-1     NVP-TAE684          1   156.25
# 1     50029-3      MCF7      10024-101-1     NVP-TAE684          1   312.50
# 2     50029-3      MCF7      10024-101-1     NVP-TAE684          1   625.00
# 3     50029-3      MCF7      10024-101-1     NVP-TAE684          1  1250.00
# 4     50029-3      MCF7      10024-101-1     NVP-TAE684          1  2500.00
#
#      IC50    EC50    Emax    Einf  ...  \
# 0  0.1519  0.0644  0.3193  0.3262  ...
# 1  0.4509  0.2457  0.2754  0.2733  ...
# 2  0.2192  0.0990  0.2678  0.2470  ...
# 3  0.1798  0.1022  0.2463  0.2465  ...
# 4  0.1816  0.1092  0.2284  0.2285  ...
#
#                                         IC_Curve_Fit   IC_r2    GR50   GEC50  \
# 0  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.6193  0.0650  0.0749
# 1  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9794  0.2018  0.2687
# 2  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9380  0.0695  0.1098
# 3  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9930  0.0842  0.1223
# 4  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9869  0.0998  0.1392
#
#     GRmax   GRinf  GR_Hill_Coeff  GR_AOC  \
# 0 -0.1298 -0.1020         1.3170  0.6318
# 1 -0.2296 -0.2307         1.3254  0.5092
# 2 -0.2274 -0.2493         0.8837  0.6602
# 3 -0.2788 -0.2814         1.1945  0.6383
# 4 -0.2196 -0.2296         1.1347  0.5990
#
#                                         GR_Curve_Fit   GR_r2
# 0  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.6437
# 1  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9843
# 2  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9391
# 3  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9948
# 4  sigmoidal fit: x = Einf + (1-Einf)/(1+ (x/EC50...  0.9911
#
# [5 rows x 22 columns]
# mep :	size (9248, 18)
#   Cell_HMSLID Cell_Line Clinical_Subtype Transcriptional_Subtype  \
# 0     51088-1     184A1               NM                   Basal
# 1     51088-1     184A1               NM                   Basal
# 2     51088-1     184A1               NM                   Basal
# 3     51088-1     184A1               NM                   Basal
# 4     51088-1     184A1               NM                   Basal
#
#   Perturbagen_HMSLID             Perturbagen Perturbagen_Target  \
# 0        10275-101-1  (Z)-4-Hydroxytamoxifen               ESR1
# 1        10236-101-1                  17-AAG              HSP90
# 2        10237-101-1                  5-DFUR               TYMS
# 3        10238-101-1                    5-FU               TYMS
# 4        10133-101-2                Afatinib          EGFR/HER2
#
#   Perturbagen_Class  Replicate_ID Conc_Unit       GR50       GEC50   GRmax  \
# 0               NaN      9047.132        uM        inf         inf  0.4055
# 1             HSP90      9047.037        uM    0.00930     0.01282 -0.9826
# 2              TYMS     12509.143        uM  228.63720  1000.00000 -0.2404
# 3              TYMS      9047.017        uM   48.19500    95.97100 -0.8459
# 4              ErbB     12509.165        uM    0.02251     0.33740 -0.9088
#
#     GRinf  GR_Hill_Coeff  GR_AOC   GR_r2  Nominal_Div_Rate
# 0  0.4055         0.0000  0.2074  0.3073            0.6985
# 1 -0.6989         2.7212  1.1760  0.9539            0.5262
# 2 -0.6424         0.5600  0.2642  0.9697            1.3392
# 3 -0.8556         1.4480  0.8094  0.9747            0.8440
# 4 -1.0000         0.4058  0.8284  0.9307            1.5022

# %%
klaeger_drugs = set([x.lower().replace('-', '') for x in klaeger_drugs])

for name,data in datadict.items():
    try:
        local_drug_set = set(data.Perturbagen)
    except:
        local_drug_set = set(data.Small_Molecule)
        
    local_drug_set = set([x.lower().replace('-','').replace(' ', '') for x in local_drug_set])
    
    print(len(local_drug_set), 'total drugs in', name)
    print(np.round(len(local_drug_set & klaeger_drugs)*100.0/len(klaeger_drugs),3), '% of Klaeger present\n')
# Out:
# 107 total drugs in broad_hms
# 21.659 % of Klaeger present
#
# 16 total drugs in genentech
# 1.382 % of Klaeger present
#
# 8 total drugs in lincs_mcf
# 1.843 % of Klaeger present
#
# 545 total drugs in ctrp
# 29.032 % of Klaeger present
#
# 12 total drugs in hms_density
# 2.765 % of Klaeger present
#
# 107 total drugs in mep
# 7.373 % of Klaeger present

# %%
for name, data in datadict.items():
    # splice molecule into a different field
    # remove '-' and ' ' from molecule names
    try:
        data['molecule'] = copy(data.Perturbagen.apply(lambda x: x.lower().replace('-', '').replace(' ', '')))
    except:
        data['molecule'] = copy(data.Small_Molecule.apply(lambda x: x.lower().replace('-', '').replace(' ', '')))
        
    # rename cellline 
    data['cellline'] = copy(data.Cell_Line.apply(lambda x: x.lower().replace('-', '').replace(' ', '')))    
        
    data = data[['molecule', 'cellline', 'GR50', 'GRmax', 'GRinf', 'GR_Hill_Coeff', 'GR_AOC', 'GR_r2']]
        
    datadict[name] = data

# %%
agg = pd.concat([data for data in datadict.values()], ignore_index=True)
display(agg.shape)
display(agg.head(10))
display(agg.describe())
# Out:
# (83162, 8)
#      molecule cellline      GR50     GRmax     GRinf  GR_Hill_Coeff   GR_AOC  \
# 0  seliciclib     bt20  5.677700  0.194160 -1.000000        1.17820  0.17548
# 1     a443654     bt20  0.053033 -0.492210 -0.633570        0.55758  1.00120
# 2    afatinib     bt20       inf  0.054486  0.683190        0.01000  0.25541
# 3      at7519     bt20  0.204440 -0.401780 -0.405630        1.32240  0.86351
# 4     azd5438     bt20  0.245910 -0.354640 -0.446100        0.79155  0.74810
# 5     azd6482     bt20  1.286700 -0.081485 -0.548250        0.76277  0.42682
# 6     azd7762     bt20  0.653730 -0.407380 -0.569420        1.00760  0.58180
# 7     azd8055     bt20      -inf -0.223940 -1.000000        0.16953  0.92212
# 8     azd8330     bt20       inf  0.784780  0.748880        0.01000  0.24961
# 9  barasertib     bt20  0.246680 -0.013290 -0.066258        0.71297  0.64146
#
#           GR_r2
# 0  9.722700e-01
# 1  9.874300e-01
# 2 -1.060000e-12
# 3  9.993600e-01
# 4  9.909100e-01
# 5  9.988100e-01
# 6  9.895100e-01
# 7  9.223300e-01
# 8  0.000000e+00
# 9  9.919900e-01
#                GR50         GRmax         GRinf  GR_Hill_Coeff        GR_AOC  \
# count  8.316200e+04  83162.000000  83162.000000   83162.000000  83162.000000
# mean            NaN      0.001954     -0.169606       1.986911      0.301824
# std             NaN      0.697329      0.755661       1.851131      0.317119
# min            -inf     -1.000000     -1.000000       0.000000     -0.112400
# 25%    1.336025e+00     -0.666708     -0.980508       0.417700      0.058600
# 50%    1.549750e+01     -0.042000     -0.324870       1.335800      0.209990
# 75%             inf      0.689810      0.583223       3.605475      0.452308
# max             inf      1.143600      1.050000       5.000000      1.998600
#
#              GR_r2
# count  83162.00000
# mean          -inf
# std            NaN
# min           -inf
# 25%        0.53752
# 50%        0.90822
# 75%        0.97353
# max        1.00000

# %%
plt.hist(agg[np.abs(agg.GR_r2) < 10].GR_r2)
plt.show()

# %%
agg[agg.GR_r2 == agg.GR_r2.min()]
# Out:
#             molecule     cellline  GR50  GRmax  GRinf  GR_Hill_Coeff  GR_AOC  \
# 5471       docetaxel         rcm1  31.0   1.05   1.05            0.0   -0.05
# 6723           ms275        umc11  31.0   1.05   1.05            0.0   -0.05
# 20519      bms536924          es2   inf   1.05   1.05            0.0   -0.05
# 20712          pik93          es2   inf   1.05   1.05            0.0   -0.05
# 20753           tw37          es2   inf   1.05   1.05            0.0   -0.05
# 20777  betulinicacid          es2   inf   1.05   1.05            0.0   -0.05
# 20923    sitagliptin          es2   inf   1.05   1.05            0.0   -0.05
# 23301           agk2      hcc1806   inf   1.05   1.05            0.0   -0.05
# 23318      bms536924      hcc1806   inf   1.05   1.05            0.0   -0.05
# 23472          ml029      hcc1806   inf   1.05   1.05            0.0   -0.05
# 23488          npc26      hcc1806   inf   1.05   1.05            0.0   -0.05
# 23551           tw37      hcc1806   inf   1.05   1.05            0.0   -0.05
# 23575  betulinicacid      hcc1806   inf   1.05   1.05            0.0   -0.05
# 36217   brdk92856060        kms26   inf   1.05   1.05            0.0   -0.05
# 36482   parthenolide        kms26   inf   1.05   1.05            0.0   -0.05
# 39815   brdk92856060         ln18   inf   1.05   1.05            0.0   -0.05
# 39849  compound1541a         ln18   inf   1.05   1.05            0.0   -0.05
# 54898   parthenolide       ncin87   inf   1.05   1.05            0.0   -0.05
# 72925      nilotinib         mcf7   inf   1.05   1.05            0.0   -0.05
# 72966      erlotinib         mcf7   inf   1.05   1.05            0.0   -0.05
# 72967      erlotinib         mcf7   inf   1.05   1.05            0.0   -0.05
# 72968      erlotinib         mcf7   inf   1.05   1.05            0.0   -0.05
# 72972      nilotinib         mcf7   inf   1.05   1.05            0.0   -0.05
# 73068   methotrexate        skbr3   inf   1.05   1.05            0.0   -0.05
# 73093      nilotinib        skbr3   inf   1.05   1.05            0.0   -0.05
# 73094      nilotinib        skbr3   inf   1.05   1.05            0.0   -0.05
# 73249        plx4720     mdamb231   inf   1.05   1.05            0.0   -0.05
# 73260      nilotinib     mdamb231   inf   1.05   1.05            0.0   -0.05
# 73284   methotrexate     mdamb231   inf   1.05   1.05            0.0   -0.05
# 73381      nilotinib         bt20   inf   1.05   1.05            0.0   -0.05
# ...              ...          ...   ...    ...    ...            ...     ...
# 74626     pemetrexed         bt20   inf   1.05   1.05            0.0   -0.05
# 74627     pemetrexed         bt20   inf   1.05   1.05            0.0   -0.05
# 74947      cetuximab        bt483   inf   1.05   1.05            0.0   -0.05
# 75908      cisplatin      hcc1395   inf   1.05   1.05            0.0   -0.05
# 76535      cetuximab      hcc1569   inf   1.05   1.05            0.0   -0.05
# 76825     pemetrexed      hcc1806   inf   1.05   1.05            0.0   -0.05
# 78197      baicalein       hs578t   inf   1.05   1.05            0.0   -0.05
# 78217      cetuximab       hs578t   inf   1.05   1.05            0.0   -0.05
# 78244      erlotinib       hs578t   inf   1.05   1.05            0.0   -0.05
# 78245      erlotinib       hs578t   inf   1.05   1.05            0.0   -0.05
# 78512        l779450          ly2   inf   1.05   1.05            0.0   -0.05
# 78550         ps1145          ly2   inf   1.05   1.05            0.0   -0.05
# 78566       tcspim11          ly2   inf   1.05   1.05            0.0   -0.05
# 78567       tcspim11          ly2   inf   1.05   1.05            0.0   -0.05
# 78592       zm447439          ly2   inf   1.05   1.05            0.0   -0.05
# 78811     pemetrexed       mcf10a   inf   1.05   1.05            0.0   -0.05
# 79396      cetuximab   mdamb134vi   inf   1.05   1.05            0.0   -0.05
# 79761      cetuximab  mdamb175vii   inf   1.05   1.05            0.0   -0.05
# 80151      gw843682x     mdamb361   inf   1.05   1.05            0.0   -0.05
# 80248          sb3ct     mdamb361   inf   1.05   1.05            0.0   -0.05
# 80329       as252424     mdamb415   inf   1.05   1.05            0.0   -0.05
# 80331      baicalein     mdamb415   inf   1.05   1.05            0.0   -0.05
# 80351      cisplatin     mdamb415   inf   1.05   1.05            0.0   -0.05
# 80479    selumetinib     mdamb415   inf   1.05   1.05            0.0   -0.05
# 80593       ly294002     mdamb436   inf   1.05   1.05            0.0   -0.05
# 81319    gsk1838705a   sum1315mo2   inf   1.05   1.05            0.0   -0.05
# 81385     pemetrexed   sum1315mo2   inf   1.05   1.05            0.0   -0.05
# 81402      sorafenib   sum1315mo2   inf   1.05   1.05            0.0   -0.05
# 81807      cetuximab     sum185pe   inf   1.05   1.05            0.0   -0.05
# 81911      celecoxib    sum225cwn   inf   1.05   1.05            0.0   -0.05
#
#        GR_r2
# 5471    -inf
# 6723    -inf
# 20519   -inf
# 20712   -inf
# 20753   -inf
# 20777   -inf
# 20923   -inf
# 23301   -inf
# 23318   -inf
# 23472   -inf
# 23488   -inf
# 23551   -inf
# 23575   -inf
# 36217   -inf
# 36482   -inf
# 39815   -inf
# 39849   -inf
# 54898   -inf
# 72925   -inf
# 72966   -inf
# 72967   -inf
# 72968   -inf
# 72972   -inf
# 73068   -inf
# 73093   -inf
# 73094   -inf
# 73249   -inf
# 73260   -inf
# 73284   -inf
# 73381   -inf
# ...      ...
# 74626   -inf
# 74627   -inf
# 74947   -inf
# 75908   -inf
# 76535   -inf
# 76825   -inf
# 78197   -inf
# 78217   -inf
# 78244   -inf
# 78245   -inf
# 78512   -inf
# 78550   -inf
# 78566   -inf
# 78567   -inf
# 78592   -inf
# 78811   -inf
# 79396   -inf
# 79761   -inf
# 80151   -inf
# 80248   -inf
# 80329   -inf
# 80331   -inf
# 80351   -inf
# 80479   -inf
# 80593   -inf
# 81319   -inf
# 81385   -inf
# 81402   -inf
# 81807   -inf
# 81911   -inf
#
# [67 rows x 8 columns]

# %% [markdown]
# ### This section contains the NaN, inf, and nonsense removal steps from the GRMetrics data

# %%
agg['inf_50'] = 1.0*(agg.GR50==agg.GR50.max())
agg['missing_50'] = 1.0*(agg.GR50==agg.GR50.min())
agg['normal_50'] = 1.0-agg.inf_50.values-agg.missing_50.values

# replace inf values in GR50
agg['GR50'] = copy(agg.GR50.replace(agg.GR50.min(), -2).replace(agg.GR50.max(), -1))

# shifted log transform of GR50
agg['GR50'] = copy(agg.GR50).apply(lambda x: np.log(x+1) if x > -1 else x)

# drop the -inf r2 values
agg.drop(agg[agg.GR_r2 == agg.GR_r2.min()].index, axis=0, inplace = True)

# drop weird r2 values -- may want to add np.isclose for precision issues
agg = agg[agg.GR_r2 >= -1.0]

# drop weird GRinf values -- ditto np.close
agg = agg[agg.GRinf <= 1.0]

# drop weird GRmax values -- ditto
agg = agg[agg.GRmax <= 1.0]

# average the remaining cell lines

# %%
agg.describe()
# Out:
#                GR50         GRmax         GRinf  GR_Hill_Coeff        GR_AOC  \
# count  76241.000000  76241.000000  76241.000000   76241.000000  76241.000000
# mean       1.275822     -0.091718     -0.275250       2.139678      0.328650
# std        1.845113      0.651858      0.697033       1.826794      0.315856
# min       -2.000000     -1.000000     -1.000000       0.000000     -0.112400
# 25%        0.008541     -0.709990     -0.999700       0.640290      0.085580
# 50%        0.975012     -0.154890     -0.452930       1.495100      0.241400
# 75%        2.766445      0.513490      0.345640       3.976000      0.479500
# max        9.597628      1.000000      1.000000       5.000000      1.998600
#
#               GR_r2        inf_50    missing_50     normal_50
# count  76241.000000  76241.000000  76241.000000  76241.000000
# mean       0.771073      0.210884      0.003738      0.785378
# std        0.317369      0.407939      0.061026      0.410563
# min       -0.996840      0.000000      0.000000      0.000000
# 25%        0.694810      0.000000      0.000000      1.000000
# 50%        0.925100      0.000000      0.000000      1.000000
# 75%        0.976470      0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000

# %%
pd.plotting.scatter_matrix(agg[agg.columns[2:8]].sample(200),diagonal='kde', alpha=.3, figsize=(10,10))
plt.show()

# %%
agg.to_csv('../data/modelInputs/input_grMetrics.tsv', sep='\t', index=False, header=True)
